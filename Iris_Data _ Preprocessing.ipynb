# %%
import os 
import pandas as pd
path = os.path.dirname(os.path.realpath('__file__'))
print(path)
iris_data= pd.read_csv(path + '\\ML\\Iris.csv')
iris_data.iloc[98 : 105]
# Out:
# C:\Users\Rowida Nagah
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 98    99            5.1           2.5            3.0           1.1
# 99   100            5.7           2.8            4.1           1.3
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
#
#              Species
# 98   Iris-versicolor
# 99   Iris-versicolor
# 100   Iris-virginica
# 101   Iris-virginica
# 102   Iris-virginica
# 103   Iris-virginica
# 104   Iris-virginica

# %%
import matplotlib.pyplot as plt 
iris_data.hist(bins=50 , figsize=(20,15))
plt.show()

# %%
import numpy as np
x1 = np.c_[iris_data.SepalLengthCm]
x2 = np.c_[iris_data["PetalLengthCm" ]]
x3 = iris_data.PetalWidthCm

# %%
print(iris_data.isnull().sum())
print()
iris_data.describe()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
a = len(iris_data)
for i in range(a):
    if iris_data.Species[i] == 'Iris-setosa':
        iris_data.Species[i] = 0
    elif iris_data.Species[i] == 'Iris-versicolor':
        iris_data.Species[i] = 1
    elif iris_data.Species[i] == 'Iris-virginica':
        iris_data.Species[i] = 2
print(iris_data.Species.iloc[20:26])
print()
iris_data.Species.iloc[97:110]
# Out:
# 20    0
# 21    0
# 22    0
# 23    0
# 24    0
# 25    0
# Name: Species, dtype: object
# 97     1
# 98     1
# 99     1
# 100    2
# 101    2
# 102    2
# 103    2
# 104    2
# 105    2
# 106    2
# 107    2
# 108    2
# 109    2
# Name: Species, dtype: object

# %%
iris_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB
