# %%
import numpy as np
import cvxopt
from sklearn.datasets.samples_generator import make_blobs
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
from sklearn.svm import LinearSVC
from sklearn.metrics import confusion_matrix

# %%
import os 
import pandas as pd 
path = os.path.dirname(os.path.realpath('__file__'))
df = pd.read_csv(path + '\\ML\\winequality-red.csv' , sep=';')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
iris = pd.read_csv(path + '\\ML\\Iris.csv')
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.subplot()
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)
plt.plot(x ,y)
plt.show()

# %%
plt.subplots(1, 2, sharey=True)
plt.show()

# %%
fig, ax = plt.subplots()
plt.show()

# %%
f, ax = plt.subplots()
ax.scatter(iris['SepalLengthCm'], iris['SepalWidthCm'] , c = iris.SepalLengthCm)
iris.columns
#plt.show()
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
l=LabelEncoder()
l.fit(iris.Species.drop_duplicates())
iris.Species=l.transform(iris.Species)
fig, ax = plt.subplots()
for i in range(len(iris.Species )):
    ax.scatter(iris['SepalLengthCm'], iris['SepalLengthCm'] , c= (iris.Species+102))
plt.show()

# %%
(iris.Species+2).iloc[100:105]
# Out:
# 100    4
# 101    4
# 102    4
# 103    4
# 104    4
# Name: Species, dtype: int64

# %%
x = iris.columns.drop(['Species'])
fig, ax = plt.subplots()
x_data = range(0, iris.shape[0])
for j in x:
    ax.plot(x_data, iris[x])
plt.show()

# %%
plt.hist(df.quality)
# Out:
# (array([ 10.,   0.,  53.,   0., 681.,   0., 638.,   0., 199.,  18.]),
#  array([3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. , 7.5, 8. ]),
#  <a list of 10 Patch objects>)

# %%
data = df['quality'].value_counts() 
data
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
points = data.index 
points
# Out:
# Int64Index([5, 6, 7, 4, 8, 3], dtype='int64')

# %%
frequency = data.values 
frequency
# Out:
# array([681, 638, 199,  53,  18,  10], dtype=int64)

# %%
fig, ax = plt.subplots() 
ax.bar(points, frequency)
# Out:
# <BarContainer object of 6 artists>

# %%
iris.plot.scatter(x='SepalLengthCm', y='SepalWidthCm', title='Iris Dataset'  ,  c = iris.SepalLengthCm )

# %%
plt.scatter(iris.SepalLengthCm, iris.SepalWidthCm ,  c = iris.SepalLengthCm)
plt.show()

# %%
plt.scatter(iris.SepalLengthCm, iris.SepalWidthCm ,  c = iris.SepalWidthCm)
plt.show()

# %%
iris.plot.scatter(x='SepalLengthCm', y='SepalWidthCm', title='Iris Dataset'  ,  c = iris.SepalWidthCm )

# %%
import seaborn as sns
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm' , hue = iris.SepalWidthCm, data=iris)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="total_bill", y="tip", data=tips)

# %%
sns.distplot(df['quality'], bins=10, kde=False)

# %%
sns.distplot(df['quality'], bins=10, kde=True)
# Out:
# C:\Users\Rowida Nagah\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
g = sns.FacetGrid(iris, col='Species')
g = g.map(sns.kdeplot, 'SepalLengthCm')
# Out:
# C:\Users\Rowida Nagah\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.pairplot(iris)

# %%
DS = pd.read_csv(path + '\\ML\\Salary_Data.csv')
sns.pairplot(DS)

# %%
plt.scatter(DS.YearsExperience , DS.Salary)
plt.legend()

# %%
plt.scatter(DS.YearsExperience , DS.Salary)

# %%
x,x1,x2 = 50 ,50 ,50
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-95-04b34da1cbbc> in <module>()
# ----> 1 x,x1,x2 = [50]
#
# ValueError: not enough values to unpack (expected 3, got 1)
